# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('data/kaggle_significant_earthquakes_database.csv')

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN  \
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Horizontal Error
# 0                     NaN        6.0             MW  ...               NaN  \
# 1                     NaN        5.8             MW  ...               NaN
# 2                     NaN        6.2             MW  ...               NaN
# 3                     NaN        5.8             MW  ...               NaN
# 4                     NaN        5.8             MW  ...               NaN
#
#    Root Mean Square            ID  Source  Location Source  Magnitude Source
# 0               NaN  ISCGEM860706  ISCGEM           ISCGEM            ISCGEM  \
# 1               NaN  ISCGEM860737  ISCGEM           ISCGEM            ISCGEM
# 2               NaN  ISCGEM860762  ISCGEM           ISCGEM            ISCGEM
# 3               NaN  ISCGEM860856  ISCGEM           ISCGEM            ISCGEM
# 4               NaN  ISCGEM860890  ISCGEM           ISCGEM            ISCGEM
#
#       Status date_parsed  year month
# 0  Automatic  1965-01-02  1965  1965
# 1  Automatic  1965-01-04  1965  1965
# 2  Automatic  1965-01-05  1965  1965
# 3  Automatic  1965-01-08  1965  1965
# 4  Automatic  1965-01-09  1965  1965
#
# [5 rows x 24 columns]

# %%
def magnitude_classification(dataframe: pd.DataFrame):
    """
    Classify earthquakes based on magnitude.

    Parameters
    ----------
    dataframe : pd.DataFrame
        Dataframe containing earthquake data

    Returns
    -------
    str
        Returns the classification of the earthquake as a string.
    """
    if dataframe['Magnitude'] >= 5.0 and dataframe['Magnitude'] <= 5.9:
        return 'Moderate (5.0-5.9)'
    elif dataframe['Magnitude'] >= 6.0 and dataframe['Magnitude'] <= 6.9:
        return 'Strong (6.0-6.9)'
    elif dataframe['Magnitude'] >= 7.0 and dataframe['Magnitude'] <= 7.9:
        return 'Major (7.0-7.9)'
    elif dataframe['Magnitude'] >= 8.0:
        return 'Great (>8.0)'

# %%
df['Class'] = df.apply(magnitude_classification, axis=1)

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60  \
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...
# 0              NaN                     NaN        6.0             MW  ...  \
# 1              NaN                     NaN        5.8             MW  ...
# 2              NaN                     NaN        6.2             MW  ...
# 3              NaN                     NaN        5.8             MW  ...
# 4              NaN                     NaN        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Root Mean Square            ID  Source  Location Source
# 0                   NaN  ISCGEM860706  ISCGEM           ISCGEM  \
# 1                   NaN  ISCGEM860737  ISCGEM           ISCGEM
# 2                   NaN  ISCGEM860762  ISCGEM           ISCGEM
# 3                   NaN  ISCGEM860856  ISCGEM           ISCGEM
# 4                   NaN  ISCGEM860890  ISCGEM           ISCGEM
# ...                 ...           ...     ...              ...
# 23407            0.1898    NN00570710      NN               NN
# 23408            0.2187    NN00570744      NN               NN
# 23409            1.5200    US10007NAF      US               US
# 23410            1.4300    US10007NL0      US               US
# 23411            0.9100    US10007NTD      US               US
#
#        Magnitude Source     Status date_parsed  year month               Class
# 0                ISCGEM  Automatic  1965-01-02  1965  1965    Strong (6.0-6.9)
# 1                ISCGEM  Automatic  1965-01-04  1965  1965  Moderate (5.0-5.9)
# 2                ISCGEM  Automatic  1965-01-05  1965  1965    Strong (6.0-6.9)
# 3                ISCGEM  Automatic  1965-01-08  1965  1965  Moderate (5.0-5.9)
# 4                ISCGEM  Automatic  1965-01-09  1965  1965  Moderate (5.0-5.9)
# ...                 ...        ...         ...   ...   ...                 ...
# 23407                NN   Reviewed  2016-12-28  2016  2016  Moderate (5.0-5.9)
# 23408                NN   Reviewed  2016-12-28  2016  2016  Moderate (5.0-5.9)
# 23409                US   Reviewed  2016-12-28  2016  2016  Moderate (5.0-5.9)
# 23410                US   Reviewed  2016-12-29  2016  2016    Strong (6.0-6.9)
# 23411                US   Reviewed  2016-12-30  2016  2016  Moderate (5.0-5.9)
#
# [23412 rows x 25 columns]

# %% [markdown]
# ### Creating a Plot

# %%
g = sns.FacetGrid(df)

# %% [markdown]
# ### Scatter Plots in FacetGrid

# %%
g = sns.FacetGrid(df)
g.map(sns.scatterplot, 'year', 'Magnitude', alpha=0.5)

# %% [markdown]
# ### Adding Columns to the FacetGrid

# %%
# FaceGrid puedes dividir tus datos en subconjuntos basados en una o más variables categóricas y 
# luego representar cada uno de estos subconjuntos en un gráfico individual
# Puede añadir columnas (col) y/o filas (row) al FaceGrid
g = sns.FacetGrid(df, col='Type')
g.map(sns.scatterplot, 'year', 'Magnitude', alpha=0.5)

# %%
g = sns.FacetGrid(df, col='Type')
g.map(sns.scatterplot, 'year','Depth', alpha=0.5)
g.set(ylim=(750, 0))

# %% [markdown]
# ### Adding Columns and Rows to the FaceGrid

# %%
g = sns.FacetGrid(df, col='Type', row='Class')
g.map(sns.scatterplot, 'year', 'Depth', alpha=0.5)
g.set(ylim=(750, 0))

# %% [markdown]
# ### Cleaning Up Subplot Titles

# %%
g = sns.FacetGrid(df, col='Type', row='Class')
g.map(sns.scatterplot, 'year', 'Depth', alpha=0.5)
g.set_titles(col_template = '{col_name}', row_template='{row_name}')
g.set(ylim=(750,0))

# %% [markdown]
# ### Ordering the Subplots in FacetGrid

# %%
g = sns.FacetGrid(df, col='Type', row='Class', 
                  row_order=['Moderate (5.0-5.9)','Strong (6.0-6.9)',  'Major (7.0-7.9)', 'Great (>8.0)'])
g.map(sns.scatterplot, 'year', 'Depth', alpha=0.5)
g.set_titles(col_template='{col_name}', row_template='{row_name}')
g.set(ylim=(750,0))

# %% [markdown]
# ### Histograms in FacetGrid

# %%
g = sns.FacetGrid(df, col='Type')
g.map(sns.histplot, 'year')

# %%
g = sns.FacetGrid(df, col='Type')
g.map(sns.histplot, 'year', bins=5)

# %% [markdown]
# ### Boxplots in FacetGrid

# %%
g = sns.FacetGrid(df, col='Type')
g.map(sns.boxplot, 'Magnitude')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:712: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
